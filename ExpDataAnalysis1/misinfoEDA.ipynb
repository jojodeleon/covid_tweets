# %% [markdown]
# ## ESOC (Empirical Studies of Conlict) COVID-19 Misinformation Dataset
# ### Misinformation is from 01/2020 - 12/2020
# #### Has headline (column named title), (publication)date, summary (of article/tweet)

# %%
import pandas as pd

# %%
misinfo = pd.read_csv('~/Documents/Flatiron/Phase_5/Data/Datasets/covid_misinfo.csv')

# %%
misinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5636 entries, 0 to 5635
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_no                     5636 non-null   int64
#  1   Reported_On              5612 non-null   object
#  2   Additional_Reporting     288 non-null    object
#  3   Retrieve_from_1          2456 non-null   object
#  4   Retrieve_from_2          504 non-null    object
#  5   Retrieve_from_3          252 non-null    object
#  6   Twitter_Reference        5613 non-null   float64
#  7   Direct_Post_1            1720 non-null   object
#  8   Direct_Post_2            699 non-null    object
#  9   Direct_Post_3            398 non-null    object
#  10  Direct_Post_4            266 non-null    object
#  11  Title                    5596 non-null   object
#  12  Publication_Date         5613 non-null   object
#  13  Entry_Date               5613 non-null   object
# ...

# %%
misinfo
# Out:
#       s_no                                        Reported_On  \
# 0        1  https://www.buzzfeednews.com/article/ryanhates...
# 1        2  https://twitter.com/Rangoli_A/status/122779241...
# 2        3  https://twitter.com/Woppa1Woppa/status/1220068...
# 3        4  https://twitter.com/FreddiGoldstein/status/123...
# 4        5  https://www.boomlive.in/health/hoax-alert-vira...
# ...    ...                                                ...
# 5631  5633                                                NaN
# 5632  5634                                                NaN
# 5633  5635                                                NaN
# 5634  5636                                                NaN
# 5635  5637                                                NaN
#
#      Additional_Reporting                                    Retrieve_from_1  \
# 0                     NaN  https://www.buzzfeednews.com/article/ryanhates...
# ...

# %%
misinfo.Main_Narrative
# Out:
# 0       Origin of the virus
# 1       Emergency responses
# 2       Origin of the virus
# 3       Emergency responses
# 4       Emergency responses
#                ...
# 5631                    NaN
# 5632                    NaN
# 5633                    NaN
# 5634                    NaN
# 5635                    NaN
# Name: Main_Narrative, Length: 5636, dtype: object

# %%
misinfo.Summary[0]
# Out:
# 'Hindi language Youtube account suggesting COVID-19 came from "Chinese people eating bat soup."'

# %%
misinfo.Title[0]
# Out:
# 'India Is In The Middle Of A Coronavirus YouTube Frenzy, And It’s Going To Get People Killed'

# %%
misinfo.Publication_Date
# Out:
# 0       19-Feb-20
# 1       12-Feb-20
# 2        3-Feb-20
# 3       12-Mar-20
# 4       28-Jan-20
#           ...
# 5631          NaN
# 5632          NaN
# 5633          NaN
# 5634          NaN
# 5635          NaN
# Name: Publication_Date, Length: 5636, dtype: object

# %%
misinfo['real_or_fake'] = 1

# %%
misinfo_eng = misinfo[misinfo.Primary_Language == 'English']
misinfo_eng
# Out:
#       s_no                                        Reported_On  \
# 0        1  https://www.buzzfeednews.com/article/ryanhates...
# 1        2  https://twitter.com/Rangoli_A/status/122779241...
# 2        3  https://twitter.com/Woppa1Woppa/status/1220068...
# 3        4  https://twitter.com/FreddiGoldstein/status/123...
# 4        5  https://www.boomlive.in/health/hoax-alert-vira...
# ...    ...                                                ...
# 5538  5539  https://leadstories.com/hoax-alert/2020/09/fac...
# 5539  5540  https://leadstories.com/hoax-alert/2020/09/fac...
# 5540  5541  https://leadstories.com/hoax-alert/2020/09/fac...
# 5584  5585   https://navi.fij.info/factcheck_navi/sfss201212/
# 5587  5588  http://www.mythdetector.ge/en/myth/report-if-j...
#
#      Additional_Reporting                                    Retrieve_from_1  \
# 0                     NaN  https://www.buzzfeednews.com/article/ryanhates...
# ...

# %%
misinfo_headlines = pd.DataFrame([misinfo_eng.Title, misinfo_eng.real_or_fake]).T
misinfo_headlines
# Out:
#                                                   Title real_or_fake
# 0     India Is In The Middle Of A Coronavirus YouTub...            1
# 1     Tweet: False reporting on "shooting down" peop...            1
# 2     Tweet: A woman eating a delicacy, attributing ...            1
# 3     Tweet: False chain message about NYPD containm...            1
# 4     Hoax Alert: Viral 'Emergency Notification' On ...            1
# ...                                                 ...          ...
# 5538  Fact Check: There Are Currently NO Vaccines Av...            1
# 5539  Fact Check: 'PCR' Test For COVID Does NOT Infl...            1
# 5540  Fact Check: COVID-19 Is NOT 'The Most Highly S...            1
# 5584  It is clear that Go To Travel users are experi...            1
# 5587  Report as if Japanese scientist speaks about m...            1
#
# [1504 rows x 2 columns]

# %%
misinfo_headlines.dropna(inplace=True)
misinfo_headlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1501 entries, 0 to 5587
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         1501 non-null   object
#  1   real_or_fake  1501 non-null   object
# dtypes: object(2)
# memory usage: 35.2+ KB

# %%
misinfo_headlines.rename(columns={'Title':'headline'}, inplace=True)
misinfo_headlines
# Out:
#                                                headline real_or_fake
# 0     India Is In The Middle Of A Coronavirus YouTub...            1
# 1     Tweet: False reporting on "shooting down" peop...            1
# 2     Tweet: A woman eating a delicacy, attributing ...            1
# 3     Tweet: False chain message about NYPD containm...            1
# 4     Hoax Alert: Viral 'Emergency Notification' On ...            1
# ...                                                 ...          ...
# 5538  Fact Check: There Are Currently NO Vaccines Av...            1
# 5539  Fact Check: 'PCR' Test For COVID Does NOT Infl...            1
# 5540  Fact Check: COVID-19 Is NOT 'The Most Highly S...            1
# 5584  It is clear that Go To Travel users are experi...            1
# 5587  Report as if Japanese scientist speaks about m...            1
#
# [1501 rows x 2 columns]

# %%
misinfo_headlines.to_csv('ESOCheadlines_eng.csv', index=False)
